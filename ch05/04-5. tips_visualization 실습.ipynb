# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
tips[:10]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
pd.DataFrame(tips['sex'].value_counts())
# Out:
#         sex
# Male    157
# Female   87

# %%
pd.DataFrame(tips['smoker'].value_counts())
# Out:
#      smoker
# No      151
# Yes      93

# %%
pd.DataFrame(tips['time'].value_counts())
# Out:
#         time
# Dinner   176
# Lunch     68

# %%
pd.DataFrame(tips.groupby('day')[['total_bill','tip']].sum())
# 그룹바이 -> 인덱스로 가야지
# 그룹별로 묶어서 데이터 봐야하니까
# Out:
#       total_bill     tip
# day
# Thur     1096.33  171.83
# Fri       325.88   51.96
# Sat      1778.40  260.40
# Sun      1627.16  247.39

# %%
pd.DataFrame(tips.groupby('day')[['total_bill','tip','size']].mean())
# Out:
#       total_bill       tip      size
# day
# Thur   17.682742  2.771452  2.451613
# Fri    17.151579  2.734737  2.105263
# Sat    20.441379  2.993103  2.517241
# Sun    21.410000  3.255132  2.842105

# %%
# %matplotlib inline

# %%
import sys
print(sys.version)
# Out:
# 3.10.9 | packaged by Anaconda, Inc. | (main, Mar  1 2023, 18:18:15) [MSC v.1916 64 bit (AMD64)]

# %%
# !pip install pandas_profiling

# %%
# profiling은 그 코드내에서 주석을 쓰면 안됨.
#!pip install pandas_profiling --upgrade

# 안되는 이유를 끝까지 구글링 해야 됨. 검색어를 바꿔가면서 찾을 때까지

# %%
import pandas_profiling as pp
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_21900\1872674328.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling as pp

# %%
pp.ProfileReport(tips)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-05-23 08:25:21.370980&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# tips df를 프로파일링

# %%
titan = sns.load_dataset('titanic')
titan[:10]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
pp.ProfileReport(titan)
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:342, in BaseFormatter.__call__(self, obj)
#     340     method = get_real_method(obj, self.print_method)
#     341     if method is not None:
# --> 342         return method()
#     343     return None
#     344 else:
#
# File ~\anaconda3\lib\site-packages\typeguard\__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py:470, in ProfileReport._repr_html_(self)
#     468 def _repr_html_(self) -> None:
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(4,4))
sns.distplot(tips['total_bill']) # 히스토그램 
                    # : 수치형 변수의 빈도수 시각화
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_21900\3859408184.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_21900\1788522946.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'])
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
plt.figure(figsize=(4,4))
sns.distplot(tips['tip'])
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_21900\3355160518.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['tip'])

# %%
plt.figure(figsize=(3,3))
sns.replot(x='total_bill', y='tip', data=tips);
# Out:
# <img src="data:image/png;base64,..." width="300.26666666666665">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 plt.figure(figsize=(3,3))
# ----> 2 sns.replot(x='total_bill', y='tip', data=tips)
#
# AttributeError: module 'seaborn' has no attribute 'replot'
